# %% [markdown]
# #  <font color="darkred"> &#10070; Problème du rendu de monnaie</font>
#
# ## <font color="darkblue"> &diams; Introduction</font>

# %% [markdown]
# ![monnaie.jpg](attachment:monnaie.jpg)

# %% [markdown]
# Lorsqu'on doit rendre la monnaie, on a plusieurs possibilités. Par exemple lorsqu'il faut rendre 4,20 euros on peut donner :
# * Deux pièce de 2 euros, une pièce de 20 centimes (soit 3 pièces au total)
# * Quatre pièces de 1 euros et une pièce de 20 centimes (soit 5 pièces au total)
# * Huit pièces de 50 centimes et 4 pièces de 5 centimes (soit 12 pièces au total)
# * etc ...
#
# Le problème du rendu de monnaie consiste à chercher le nombre minimal de pièce permettant de former une somme donnée.

# %% [markdown]
# ## <font color="darkblue"> &diams; Formalisation mathématique </font>
#
# Etant une somme $S$ et un système de valeurs de pièces ou de billets : $(v_1,v_2, \dots v_n)$, il s'agit de trouver le nombre de pièces de chaque sorte $(x_1,x_2, \dots x_n)$ de telle sorte que :
#  $$S = \sum_{k=1}^{n} x_k v_k $$
#  Avec le nombre total de pièces $x_1+x_2+ \dots x_n$ minimal.
#
# ## <font color=green> &#9998; Exercices </font>
#
# 1. <font color="green"> Supposons qu'on ne dispose que de quatre valeurs de pièces : 1, 3, 4 et 5 (ce sont les valeurs $v_i$ ci dessus) et qu'il faut rendre la somme  $S=7$. Proposer une solution c'est à dire le nombre de pièce de chaque sorte sous la forme d'un quadruplet $(x_1,x_2,x_3,x_4)$ pour ce problème.</font>

# %%
# Votre réponse ici

# %% [markdown]
# ## <font color="darkblue"> &diams; Résolution par un algorithme glouton</font>
#
# Une méthode possible de résolution du problème de rendu de monnaie est d'utiliser un **algorithme glouton**, on rend la monnaie pièce par pièce en choisissant la pièce de plus forte valeur possible à chaque étape.
#
# Prenons un exemple, les valeurs sont $(1,2,5)$ et on doit rendre 9 :
# * Pièces : 5 ; Reste : 4
# * Pièces : 5,2 ; Reste : 2
# * Pièces : 5,2,2 ; Reste : 0
#
# ## <font color=green> &#9998; Exercices </font>
#
# 2. <font color="green"> Faire fonctionner cet algorithme sur le problème de l'exercice 1, pour rappel les valeurs sont (1,3,4,5) et il faut rendre 7. La solution obtenue est-elle optimale ?</font>

# %% [markdown]
# ## <font color="darkblue"> &diams; Implémentation en Python </font>

# %% [markdown]
# ## <font color=green> &#9998; Exercices </font>
#
# 3. <font color="green"> Ecrire en Python, une implémentation de l'algorithme glouton pour le rendu de monnaie.</font>

# %%
# Votre code ici

# %% [markdown]
# ## <font color="darkblue"> &diams; Pour aller plus loin ... </font>
#
# L'algorithme glouton du rendu de monnaie ne fournit pas toujours une solution optimale (voir l'exercice 2). Cependant, on montre que pour certains valeurs de pièces dites **canoniques** l'algorithme donne toujours une solution optimale. Le système des pièces et billets en euros est canonique.
# On pourra consulter [la page wikipedia dédié à ce problème](https://fr.wikipedia.org/wiki/Probl%C3%A8me_du_rendu_de_monnaie)
