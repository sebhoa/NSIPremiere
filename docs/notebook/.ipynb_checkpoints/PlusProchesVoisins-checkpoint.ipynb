# %% [markdown]
# #  <font color="darkred"> &#10070; Algorithme des k plus proches voisins</font>

# %% [markdown]
# Le but du notebook est de mettre en oeuvre en Python l'algorithme des k plus proches voisins

# %% [markdown]
# ## <font color="darkblue"> &diams; A propose de voisins ... </font>
# Remarquons que pour déterminer les voisins, il faut disposer d'une **distance** entre deux données. Cette notion mathématique de distance est difficile à formaliser et à définir de façon précise à notre niveau. On a utilisé dans l'exemple ci-dessus la **distance euclidienne** c'est à dire celle que l'on peut mesurer entre deux points à l'aide d'une règle. On rappelle que si les coordonnées de ces deux points sont $(x_1,y_1)$ et $(x_2,y_2)$ alors la distance euclidienne entre ces deux points est :
# $$ d = \sqrt{(x_2-x_1)^2+(y_2-y_1)^2} $$
# Cela a été vu dès la classe de seconde en mathématique. On admettra que cette distance se généralise si les "points" ont plus de 2 coordonnées.
#
# Enfin, d'autres distances peuvent être définies (voir la dernière partie de ce notebook).

# %% [markdown]
# ## <font color="darkblue"> &diams; Les iris de Fisher</font>

# %% [markdown]
# ![iris.png](attachment:iris.png)

# %% [markdown]
# Les [iris de Fisher](https://fr.wikipedia.org/wiki/Iris_de_Fisher) sont "un cas d'école" de l'utilisation de l'algorithme des k plus proches voisins. Sur des iris dont on connait l'espèce (Iris setosa, Iris virginica ou Iris versicolor) on a mesuré (en cm) quatre caractéristiques :
# * longueur des sépales
# * largeur des sépales
# * longueur des pétales
# * largeur des pétales
#
# Le jeu de données `iris.csv` comporte 150 lignes (50 pour chaque espèce d'Iris)

# %% [markdown]
# ## <font color=green> &#9998; Exercices </font>
#
# 6. <font color="green"> Ecrire un programme Python qui lit le fichier <code>iris.csv</code> et crée une liste `iris` contenant pour chaque iris les caractéristiques et l'espèce dans une liste. Par exemple `iris[0]` correspond à la première ligne du jeu de données et devra donc contenir [5.1,3.5,1.4,0.2,"setosa"]</font>

# %%
# Votre programme ici
# Penser à convertir les 4 premières données directement en flottant à partir du fichier iris.csv
# La première ligne contient les entêtes on pourra l'enlever des données

# %% [markdown]
# ## <font color="darkblue"> &diams; Distance entre deux iris !</font>

# %% [markdown]
# Afin de déterminer les "voisins plus proches" d'un iris, il faut pouvoir mesurer la distance entre deux iris qui sont représentés par les quatre caractéristiques. On note $(x_1,y_1,z_1,t_1)$ les caractéristiques du premier iris et $(x_2,y_2,z_2,t_2)$ celles du second. On prendra comme distance entre ces eux iris :
# $$ d = \sqrt{(x_2-x_1)^2+(y_2-y_1)^2+(z_2-z_1)^2+(t_2-t_1)^2} $$
#
# *Remarque :* D'autres distances peuvent être définies

# %% [markdown]
# ## <font color=green> &#9998; Exercices </font>
#
# 7. <font color="green"> Ecrire une fonction <code>distance</code> qui prend en argument deux listes représentant des iris (voir exercice 6) et renvoie la distance entre ces deux iris telle que définie ci-dessus.</font>

# %%
# Definition de la fonction de distance ici

# %% [markdown]
# ## <font color="darkblue"> &diams; Implémentation de l'algorithme des k plus proches voisins </font>

# %% [markdown]
# On veut classer les iris suivants dont on ne connait que les caractéristiques :
#
# <table>
#     <tr>
#         <th> Fleur </th>
#         <th> longueur sépale</th>
#         <th> largeur sépale</th>
#         <th> longueur pétale</th>
#         <th> largeur pétale</th>
#     </tr>
#     <tr>
#         <td> Iris1 </td>
#         <td> 4.8 </td>
#         <td> 3.7 </td>
#         <td> 1.9 </td>
#         <td> 0.5 </td>
#     </tr>
#     <tr>
#         <td> Iris2 </td>
#         <td> 6.0 </td>
#         <td> 2.2 </td>
#         <td> 5.4 </td>
#         <td> 1.6 </td>
#     </tr>
#     <tr>
#         <td> Iris3 </td>
#         <td> 5.5 </td>
#         <td> 2.7 </td>
#         <td> 4.0 </td>
#         <td> 1.2 </td>
#     </tr>
# </table>

# %% [markdown]
# ## <font color=green> &#9998; Exercices </font>
#
# 8. <font color="green">Définir les variables python `iris1`, `iris2` et `iris3` permettant de représenter ces trois nouveaux iris comme ceux lus à partir du fichier de données.</font>

# %%
# Votre réponse ici

# %% [markdown]
# 9. <font color="green">Proposer une implémentation de l'algorithme des k plus proches voisins utilisant la distance définie plus haut et qui permet de classer ces trois nouveaux iris.</font>

# %% [markdown]
# On peut commencer par écrire une fonction qui renvoie la liste des distances entre un iris inconnu et chacun des 150 iris du fichier de données. Puis écrire une fonction qui renvoie les indices des k éléments les plus petits de cette liste (et donc les k plus proches voisins).

# %%
# Votre programme ici (ou à écrire dans VS-Code)

# %% [markdown]
# ## <font color="darkblue"> &diams; Pour aller plus loin </font>

# %% [markdown]
# On peut consulter [la page wikipedia](https://fr.wikipedia.org/wiki/M%C3%A9thode_des_k_plus_proches_voisins) sur la méthode des k plus proches voisins.
#
# Sur la notion de distance, on peut s'intéresser à la [distance de manhattan](https://fr.wikipedia.org/wiki/Distance_de_Manhattan) ou encore à la façon dont on peut définir une distance entre deux mots : [distance de Hamming](https://fr.wikipedia.org/wiki/Distance_de_Hamming)
